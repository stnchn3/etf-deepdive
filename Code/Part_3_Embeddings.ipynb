# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.15.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.15.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 78.5 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 30.3 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.5

# %%
# !nvidia-smi
# Out:
# Mon Dec  1 03:59:15 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   39C    P0             54W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
from datetime import datetime
import time
import json
import pandas as pd

# %%
import pymongo

db_username = 'Portfolio_intelligence'
db_password = 'WMproject3'
URI = f'mongodb+srv://Portfolio_intelligence:WMproject3@cluster0.5ibriwd.mongodb.net/'

client = pymongo.MongoClient(URI)

# %%
db = client["project3"]
collection = db["wikipedia_holdings"]
print("Connected to MongoDB.")
# Out:
# Connected to MongoDB.

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['ac-x9evpbz-shard-00-00.5ibriwd.mongodb.net:27017', 'ac-x9evpbz-shard-00-02.5ibriwd.mongodb.net:27017', 'ac-x9evpbz-shard-00-01.5ibriwd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-8gdncg-shard-0', tls=True), 'project3'), 'wikipedia_holdings')

# %%
# ===============================================================
# Step 1: Load all documents that still need embedding
# ===============================================================


todo = list(collection.find({
    "wiki_content": {"$exists": True},
    "embedding": {"$exists": False}
}))
print(f"Documents to embeddings: {len(todo)}")
# Out:
# Documents to embeddings: 996

# %%
#DO NOT RUn again
collection.create_index([
    ('embeddings.model', pymongo.ASCENDING),
    ('embeddings.input', pymongo.ASCENDING),
    ('embeddings.chunk_size', pymongo.ASCENDING),
    ('embeddings.aggregation', pymongo.ASCENDING)
], name="embedding_config_compound_index")
# Out:
# 'embedding_config_compound_index'

# %%
embeddings_lst = ['BAAI/bge-small-en-v1.5','BAAI/bge-large-en-v1.5','sentence-transformers/all-mpnet-base-v2',
                  'nomic classification','nomic clustering','nomic search_query','nomic search_document']

# %% [markdown]
# ### Wiki Content

# %%
for model_str in embeddings_lst:
  embedding_config = {
    'model': model_str,
    'chunk_size': None,
    'aggregation': None,
    'input': 'wiki_content_only' # <-- Key for this pipeline
    }

  has_embedding_cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config } },
    { "_id": 1 }  # Only fetch the _id
  )
  # Create a set of _id's to ignore
  has_embedding_ids = {doc['_id'] for doc in has_embedding_cursor}
  print(f"Found {len(has_embedding_ids)} documents that already have this config for model: {model_str}.")

  # --- STEP 2: Find all docs *NOT IN* that set (this is your to-do list) ---
  needs_embedding_filter = {
    "_id": {"$nin": list(has_embedding_ids)}
  }
  # Fetch the documents that need processing
  # We explicitly include 'wiki_content' and '_id'
  cursor = collection.find(
    needs_embedding_filter,
    {'wiki_content': 1} # Only fetch wiki_content and _id (implicitly included)
  )

  todo_df = pd.DataFrame(list(cursor))
  print(f"Found {len(todo_df)} documents to process for model: {model_str}.")

  if todo_df.empty:
      print(f"No documents to process for model: {model_str}. Skipping.\n")
      continue

  # Doing the embedding - This part must be inside the loop
  if 'nomic' in model_str:
    # Load the one base model
    model = SentenceTransformer(
        'nomic-ai/nomic-embed-text-v1.5', trust_remote_code=True
    )
    # Get the prefix (e.g., "classification:")
    prefix = model_str.split()[1] + ' ' # Don't forget the space!
  else:
    model = SentenceTransformer(
        model_str, trust_remote_code=True
    )

  # Chunks by 10
  num_chunks = (len(todo_df) + 9) // 10 # ceil division
  print(f"Processing {len(todo_df)} documents in {num_chunks} chunks...")

  for i in range(num_chunks):
    start_index = i * 10
    end_index = min((i + 1) * 10, len(todo_df))
    batch_df = todo_df.iloc[start_index:end_index] # Use iloc for integer-location based indexing

    contents_to_embed = batch_df['wiki_content'].tolist()
    if 'nomic' in model_str:
      contents_to_embed = [prefix + str(d) for d in contents_to_embed]

    batch_embeddings = model.encode(contents_to_embed, normalize_embeddings=True)

    # Convert embeddings to list for MongoDB storage
    embeddings_list_of_lists = batch_embeddings.tolist()

    # Prepare bulk operations for updating documents
    updates = []
    for doc_id, embedding in zip(batch_df['_id'], embeddings_list_of_lists):
        new_embedding_doc = {
            'model': embedding_config['model'],
            'chunk_size': embedding_config['chunk_size'],
            'aggregation': embedding_config['aggregation'],
            'input': embedding_config['input'],
            'embedding': embedding # Store the actual embedding vector
        }
        updates.append(
            pymongo.UpdateOne(
                {'_id': doc_id},
                {'$push': {'embeddings': new_embedding_doc}}
            )
        )
    if updates:
        collection.bulk_write(updates)
        print(f"  Updated {len(updates)} documents with embeddings for model: {model_str} in chunk {i+1}/{num_chunks}.")
  print(f"Finished processing model: {model_str}.\n")

print("All Wikipedia embedding processed.")
# Out:
# Found 0 documents that already have this config for model: BAAI/bge-small-en-v1.5.
# Found 996 documents to process for model: BAAI/bge-small-en-v1.5.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 1/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 2/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 3/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 4/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 5/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 6/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 7/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 8/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 9/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 10/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 11/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 12/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 13/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 14/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 15/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 16/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 17/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 18/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 19/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 20/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 21/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 22/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 23/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 24/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 25/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 26/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 27/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 28/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 29/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 30/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 31/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 32/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 33/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 34/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 35/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 36/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 37/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 38/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 39/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 40/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 41/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 42/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 43/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 44/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 45/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 46/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 47/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 48/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 49/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 50/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 51/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 52/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 53/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 54/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 55/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 56/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 57/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 58/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 59/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 60/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 61/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 62/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 63/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 64/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 65/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 66/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 67/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 68/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 69/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 70/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 71/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 72/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 73/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 74/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 75/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 76/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 77/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 78/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 79/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 80/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 81/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 82/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 83/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 84/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 85/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 86/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 87/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 88/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 89/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 90/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 91/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 92/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 93/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 94/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 95/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 96/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 97/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 98/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 99/100.
#   Updated 6 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk 100/100.
# Finished processing model: BAAI/bge-small-en-v1.5.
#
# Found 0 documents that already have this config for model: BAAI/bge-large-en-v1.5.
# Found 996 documents to process for model: BAAI/bge-large-en-v1.5.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/779 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 1/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 2/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 3/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 4/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 5/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 6/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 7/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 8/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 9/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 10/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 11/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 12/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 13/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 14/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 15/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 16/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 17/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 18/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 19/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 20/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 21/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 22/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 23/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 24/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 25/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 26/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 27/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 28/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 29/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 30/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 31/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 32/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 33/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 34/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 35/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 36/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 37/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 38/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 39/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 40/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 41/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 42/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 43/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 44/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 45/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 46/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 47/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 48/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 49/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 50/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 51/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 52/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 53/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 54/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 55/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 56/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 57/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 58/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 59/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 60/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 61/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 62/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 63/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 64/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 65/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 66/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 67/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 68/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 69/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 70/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 71/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 72/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 73/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 74/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 75/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 76/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 77/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 78/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 79/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 80/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 81/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 82/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 83/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 84/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 85/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 86/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 87/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 88/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 89/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 90/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 91/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 92/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 93/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 94/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 95/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 96/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 97/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 98/100.
#   Updated 10 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 99/100.
#   Updated 6 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 100/100.
# Finished processing model: BAAI/bge-large-en-v1.5.
#
# Found 0 documents that already have this config for model: sentence-transformers/all-mpnet-base-v2.
# Found 996 documents to process for model: sentence-transformers/all-mpnet-base-v2.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 1/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 2/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 3/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 4/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 5/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 6/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 7/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 8/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 9/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 10/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 11/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 12/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 13/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 14/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 15/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 16/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 17/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 18/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 19/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 20/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 21/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 22/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 23/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 24/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 25/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 26/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 27/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 28/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 29/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 30/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 31/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 32/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 33/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 34/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 35/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 36/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 37/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 38/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 39/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 40/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 41/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 42/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 43/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 44/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 45/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 46/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 47/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 48/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 49/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 50/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 51/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 52/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 53/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 54/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 55/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 56/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 57/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 58/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 59/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 60/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 61/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 62/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 63/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 64/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 65/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 66/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 67/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 68/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 69/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 70/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 71/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 72/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 73/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 74/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 75/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 76/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 77/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 78/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 79/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 80/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 81/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 82/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 83/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 84/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 85/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 86/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 87/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 88/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 89/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 90/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 91/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 92/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 93/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 94/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 95/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 96/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 97/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 98/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 99/100.
#   Updated 6 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 100/100.
# Finished processing model: sentence-transformers/all-mpnet-base-v2.
#
# Found 0 documents that already have this config for model: nomic classification.
# Found 996 documents to process for model: nomic classification.
# modules.json:   0%|          | 0.00/255 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/140 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_hf_nomic_bert.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nomic-ai/nomic-bert-2048:
# - configuration_hf_nomic_bert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_hf_nomic_bert.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nomic-ai/nomic-bert-2048:
# - modeling_hf_nomic_bert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/547M [00:00<?, ?B/s]
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic classification in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic classification in chunk 100/100.
# Finished processing model: nomic classification.
#
# Found 0 documents that already have this config for model: nomic clustering.
# Found 996 documents to process for model: nomic clustering.
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 64/100.
# ...
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic search_query in chunk 100/100.
# Finished processing model: nomic search_query.
#
# Found 0 documents that already have this config for model: nomic search_document.
# Found 996 documents to process for model: nomic search_document.
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic search_document in chunk 100/100.
# Finished processing model: nomic search_document.
#
# All Wikipedia embedding processed.

# %% [markdown]
# ### Summary Only

# %%
for model_str in embeddings_lst:
  embedding_config = {
    'model': model_str,
    'chunk_size': None,
    'aggregation': None,
    'input': 'SUMMARY_only' # <-- Key for this pipeline
    }

  has_embedding_cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config } },
    { "_id": 1 }  # Only fetch the _id
  )
  # Create a set of _id's to ignore
  has_embedding_ids = {doc['_id'] for doc in has_embedding_cursor}
  print(f"Found {len(has_embedding_ids)} documents that already have this config for model: {model_str}.")

  # --- STEP 2: Find all docs *NOT IN* that set (this is your to-do list) ---
  needs_embedding_filter = {
    "_id": {"$nin": list(has_embedding_ids)}
  }
  # Fetch the documents that need processing
  # We specify only the fields to include
  cursor = collection.find(
    needs_embedding_filter,
    {'SUMMARY_business_description':1, 'SUMMARY_investment_exposure':1,
    'SUMMARY_investment_industry':1, 'SUMMARY_material_points':1} # Only fetch summary fields and _id (implicitly included)
  )

  todo_df = pd.DataFrame(list(cursor))
  print(f"Found {len(todo_df)} documents to process for model: {model_str}.")

  if todo_df.empty:
      print(f"No documents to process for model: {model_str}. Skipping.\n")
      continue

  # Doing the embedding - This part must be inside the loop
  if 'nomic' in model_str:
    # Load the one base model
    model = SentenceTransformer(
        'nomic-ai/nomic-embed-text-v1.5', trust_remote_code=True
    )
    # Get the prefix (e.g., "classification:")
    prefix = model_str.split()[1] + ' ' # Don't forget the space!
  else:
    model = SentenceTransformer(
        model_str, trust_remote_code=True
    )

  # Chunks by 10
  num_chunks = (len(todo_df) + 9) // 10 # ceil division
  print(f"Processing {len(todo_df)} documents in {num_chunks} chunks...")

  for i in range(num_chunks):
    start_index = i * 10
    end_index = min((i + 1) * 10, len(todo_df))
    batch_df =  todo_df.iloc[start_index:end_index] # Use iloc for integer-location based indexing

    summary_fields = [
    'SUMMARY_business_description', 'SUMMARY_investment_exposure',
    'SUMMARY_investment_industry', 'SUMMARY_material_points'
    ]
    contents_to_embed = [
        str(d) for d in batch_df[summary_fields].to_dict(orient='records')
    ]
    if 'nomic' in model_str:
      contents_to_embed = [prefix + str(d) for d in contents_to_embed]

    batch_embeddings = model.encode(contents_to_embed, normalize_embeddings=True)

    # Convert embeddings to list for MongoDB storage
    embeddings_list_of_lists = batch_embeddings.tolist()

    # Prepare bulk operations for updating documents
    updates = []
    for doc_id, embedding in zip(batch_df['_id'], embeddings_list_of_lists):
        new_embedding_doc = {
            'model': embedding_config['model'],
            'chunk_size': embedding_config['chunk_size'],
            'aggregation': embedding_config['aggregation'],
            'input': embedding_config['input'],
            'embedding': embedding # Store the actual embedding vector
        }
        updates.append(
            pymongo.UpdateOne(
                {'_id': doc_id},
                {'$push': {'embeddings': new_embedding_doc}}
            )
        )
    if updates:
        collection.bulk_write(updates)
        print(f"  Updated {len(updates)} documents with embeddings for model: {model_str} in chunk {i+1}/{num_chunks}.")
  print(f"Finished processing model: {model_str}.\n")

print("All SUMMARY embedding processed.")
# Out:
# Found 996 documents that already have this config for model: BAAI/bge-small-en-v1.5.
# Found 0 documents to process for model: BAAI/bge-small-en-v1.5.
# No documents to process for model: BAAI/bge-small-en-v1.5. Skipping.
#
# Found 990 documents that already have this config for model: BAAI/bge-large-en-v1.5.
# Found 6 documents to process for model: BAAI/bge-large-en-v1.5.
# Processing 6 documents in 1 chunks...
#   Updated 6 documents with embeddings for model: BAAI/bge-large-en-v1.5 in chunk 1/1.
# Finished processing model: BAAI/bge-large-en-v1.5.
#
# Found 0 documents that already have this config for model: sentence-transformers/all-mpnet-base-v2.
# Found 996 documents to process for model: sentence-transformers/all-mpnet-base-v2.
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 1/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 2/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 3/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 4/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 5/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 6/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 7/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 8/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 9/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 10/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 11/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 12/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 13/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 14/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 15/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 16/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 17/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 18/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 19/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 20/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 21/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 22/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 23/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 24/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 25/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 26/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 27/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 28/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 29/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 30/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 31/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 32/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 33/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 34/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 35/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 36/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 37/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 38/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 39/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 40/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 41/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 42/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 43/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 44/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 45/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 46/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 47/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 48/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 49/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 50/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 51/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 52/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 53/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 54/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 55/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 56/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 57/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 58/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 59/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 60/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 61/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 62/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 63/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 64/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 65/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 66/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 67/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 68/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 69/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 70/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 71/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 72/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 73/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 74/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 75/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 76/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 77/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 78/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 79/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 80/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 81/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 82/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 83/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 84/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 85/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 86/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 87/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 88/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 89/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 90/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 91/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 92/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 93/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 94/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 95/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 96/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 97/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 98/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 99/100.
#   Updated 6 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 100/100.
# Finished processing model: sentence-transformers/all-mpnet-base-v2.
#
# Found 0 documents that already have this config for model: nomic classification.
# Found 996 documents to process for model: nomic classification.
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic classification in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic classification in chunk 100/100.
# Finished processing model: nomic classification.
#
# Found 0 documents that already have this config for model: nomic clustering.
# Found 996 documents to process for model: nomic clustering.
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic clustering in chunk 100/100.
# Finished processing model: nomic clustering.
#
# Found 0 documents that already have this config for model: nomic search_query.
# Found 996 documents to process for model: nomic search_query.
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic search_query in chunk 100/100.
# Finished processing model: nomic search_query.
#
# Found 0 documents that already have this config for model: nomic search_document.
# Found 996 documents to process for model: nomic search_document.
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic search_document in chunk 100/100.
# Finished processing model: nomic search_document.
#
# All SUMMARY embedding processed.

# %% [markdown]
# ### Silhouette Score

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
import matplotlib.pyplot as plt

# %%
tmpdf = pd.DataFrame(collection.find(
    {},
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': {
                'model': 'BAAI/bge-small-en-v1.5',
                'chunk_size': None,
                'aggregation': None,
                'input': 'wiki_content_only'
            }
        }
    }))
embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())

# %%
def plot_silhouette_scores(embedding_array, labels, model_name):

    silhouette_vals = silhouette_samples(embedding_array, labels, metric='cosine')
    silhouette_avg = silhouette_score(embedding_array, labels, metric='cosine')

    fig, ax = plt.subplots(figsize=(10, 10))
    unique_labels = sorted(np.unique(labels))
    y_lower = 10

    for i, sector in enumerate(unique_labels):

        sector_mask = (labels == sector)
        sector_silhouette_vals = silhouette_vals[sector_mask]
        sector_silhouette_vals.sort()

        size = sector_silhouette_vals.shape[0]
        y_upper = y_lower + size

        color = plt.cm.nipy_spectral(float(i) / len(unique_labels))

        ax.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            sector_silhouette_vals,
            facecolor=color,
            edgecolor=color,
            alpha=0.7
        )

        ax.text(-0.05, y_lower + 0.5 * size, str(sector), fontsize=8)

        y_lower = y_upper + 10

    ax.axvline(
        x=silhouette_avg,
        color="red",
        linestyle="--",
        label=f"Silhouette Average: {silhouette_avg:.3f}"
    )

    ax.set_xlabel("Silhouette Coefficient")
    ax.set_ylabel("Sector")
    ax.set_title(f"Silhouette Plot for {model_name}  (Avg Score: {silhouette_avg:.2f})")
    ax.legend()
    plt.show()

    return silhouette_avg

# %%
plot_silhouette_scores(embedding_array, tmpdf.sector, 'bge-small')
# Out:
# np.float64(0.036840803694588475)

# %% [markdown]
# ### Wiki Only

# %%
wiki_content_only_silhouette = pd.Series(dtype=float)

for model_str in embeddings_lst:

    tmpdf = pd.DataFrame(collection.find(
        {},
        {
            'ticker':1,
            'sector': 1,
            'embeddings': {
                '$elemMatch': {
                    'model': model_str,
                    'chunk_size': None,
                    'aggregation': None,
                    'input': 'wiki_content_only'
                }
            }
        }
    ))

    tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]

    if len(tmpdf) == 0:
        print(f"No wiki_content_only embeddings for {model_str}")
        wiki_content_only_silhouette[model_str] = np.nan
        continue

    embedding_array = np.array([emb[0]['embedding'] for emb in tmpdf.embeddings])
    labels = tmpdf['sector']

    wiki_content_only_silhouette[model_str] = silhouette_score(
        embedding_array, labels, metric='cosine'
    )

print("SILHOUETTE SCORES (WIKI CONTENT ONLY)")
display(wiki_content_only_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY)
# BAAI/bge-small-en-v1.5                     0.036841
# BAAI/bge-large-en-v1.5                     0.037180
# sentence-transformers/all-mpnet-base-v2    0.045547
# nomic classification                      -0.007615
# nomic clustering                          -0.018137
# nomic search_query                        -0.021351
# nomic search_document                     -0.019547
# dtype: float64

# %% [markdown]
# ### Summary Only

# %%
summary_only_silhouette = pd.Series(dtype=float)

for model_str in embeddings_lst:

    tmpdf = pd.DataFrame(collection.find(
        {},
        {
            'ticker':1,
            'sector': 1,
            'embeddings': {
                '$elemMatch': {
                    'model': model_str,
                    'chunk_size': None,
                    'aggregation': None,
                    'input': 'SUMMARY_only'
                }
            }
        }
    ))

    tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]

    if len(tmpdf) == 0:
        print(f"No SUMMARY_only embeddings for {model_str}")
        summary_only_silhouette[model_str] = np.nan
        continue

    embedding_array = np.array([emb[0]['embedding'] for emb in tmpdf.embeddings])
    labels = tmpdf['sector']

    summary_only_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (SUMMARY ONLY)")
display(summary_only_silhouette)
# Out:
# SILHOUETTE SCORES (SUMMARY ONLY)
# BAAI/bge-small-en-v1.5                     0.041492
# BAAI/bge-large-en-v1.5                     0.045772
# sentence-transformers/all-mpnet-base-v2    0.045070
# nomic classification                       0.077546
# nomic clustering                           0.068625
# nomic search_query                         0.054863
# nomic search_document                      0.047128
# dtype: float64

# %% [markdown]
# ### Comparison

# %%
comparison_df = pd.DataFrame({
    "model": embeddings_lst,
    "wiki_content_silhouette": wiki_content_only_silhouette.values,
    "summary_silhouette": summary_only_silhouette.values
})

print("FINAL COMPARISON: WIKI vs SUMMARY SILHOUETTE SCORES")
display(comparison_df)
# Out:
# FINAL COMPARISON: WIKI vs SUMMARY SILHOUETTE SCORES
#                                      model  wiki_content_silhouette  \
# 0                   BAAI/bge-small-en-v1.5                 0.036841
# 1                   BAAI/bge-large-en-v1.5                 0.037180
# 2  sentence-transformers/all-mpnet-base-v2                 0.045547
# 3                     nomic classification                -0.007615
# 4                         nomic clustering                -0.018137
# 5                       nomic search_query                -0.021351
# 6                    nomic search_document                -0.019547
#
#    summary_silhouette
# 0            0.041428
# 1            0.051380
# 2            0.049855
# 3            0.081591
# 4            0.069737
# 5            0.057699
# 6            0.048393

# %% [markdown]
# ### Better

# %%
comparison_df["better_text_source"] = np.where(
    comparison_df["wiki_content_silhouette"] > comparison_df["summary_silhouette"],
    "wiki_content",
    "summary"
)

print("WHICH TEXT IS BETTER FOR EACH MODEL?")
display(comparison_df[["model", "better_text_source"]])
# Out:
# WHICH TEXT IS BETTER FOR EACH MODEL?
#                                      model better_text_source
# 0                   BAAI/bge-small-en-v1.5            summary
# 1                   BAAI/bge-large-en-v1.5            summary
# 2  sentence-transformers/all-mpnet-base-v2       wiki_content
# 3                     nomic classification            summary
# 4                         nomic clustering            summary
# 5                       nomic search_query            summary
# 6                    nomic search_document            summary

# %% [markdown]
# ### Chunking and Aggregation Test

# %%
chunks = ['250', '500', '1000']
aggregations = ['first','mean','exponential']

# %%
for chunk_size in chunks:
    chunk_size = int(chunk_size)
    for agg in aggregations:
      for model_str in embeddings_lst:

          # Build embedding_config for this run
          embedding_config = {
              'model': model_str,
              'chunk_size': chunk_size,
              'aggregation': agg,
              'input': 'wiki_content_only'
          }

          # Find docs ALREADY processed (avoid duplicates)
          has_embedding_cursor = collection.find(
              {'embeddings': {'$elemMatch': embedding_config}},
              {'_id': 1}
          )
          existing_ids = {doc['_id'] for doc in has_embedding_cursor}

          print(f"[INFO] {len(existing_ids)} docs already processed "
                f"→ model={model_str}, chunk={chunk_size}, agg={agg}")

          # Find docs still needing embeddings
          cursor = collection.find(
              {'_id': {'$nin': list(existing_ids)}},
              {'wiki_content': 1}
          )
          todo_df = pd.DataFrame(list(cursor))

          print(f"[INFO] {len(todo_df)} docs remaining "
                f"→ model={model_str}, chunk={chunk_size}, agg={agg}")

          if todo_df.empty:
              continue

          # Load model
          if 'nomic' in model_str:
              base_model = SentenceTransformer(
                  "nomic-ai/nomic-embed-text-v1.5",
                  trust_remote_code=True
              )
              prefix = model_str.split()[1] + " "
          else:
              base_model = SentenceTransformer(
                  model_str,
                  trust_remote_code=True
              )
              prefix = ""

          # Process documents in batches of 10
          num_batches = (len(todo_df) + 9) // 10

          for b in range(num_batches):
              start = b * 10
              end = min((b + 1) * 10, len(todo_df))
              batch_df = todo_df.iloc[start:end]

              # List to store (doc_id, embedding) pairs for current batch
              embeddings_to_update_in_batch = []

              # Chunk EACH DOCUMENT individually
              for idx, row in batch_df.iterrows():
                  doc_id = row['_id']
                  doc_text = row['wiki_content']

                  # Ensure we handle non-string values safely
                  if not isinstance(doc_text, str):
                      doc_text = str(doc_text)

                  # Split into chunks of LENGTH chunk_size (characters)
                  text_chunks = [
                      doc_text[i:i + chunk_size]
                      for i in range(0, len(doc_text), chunk_size)
                  ]

                  # If no chunks are generated (e.g., empty doc_text or too short), skip this document
                  if not text_chunks:
                      print(f"[WARNING] Skipping document {doc_id} (empty/short 'wiki_content') for model={model_str}, chunk={chunk_size}, agg={agg} in batch {b+1}/{num_batches}")
                      continue

                  # Add prefix for NOMIC
                  processed_text_chunks = [prefix + t for t in text_chunks]

                  # Encode each chunk
                  chunk_embs = base_model.encode(
                      processed_text_chunks,
                      normalize_embeddings=True,
                      batch_size=8 # Added to limit GPU memory usage per encoding call
                  )
                  chunk_embs = np.array(chunk_embs)

                  # Apply aggregation rule
                  final_emb = None
                  if agg == "first":
                      final_emb = chunk_embs[0]

                  elif agg == "mean":
                      final_emb = chunk_embs.mean(axis=0)

                  elif agg == "exponential":
                      weights = np.exp(-np.arange(len(chunk_embs)) / 2)
                      final_emb = np.average(chunk_embs, axis=0, weights=weights)

                  # Store the successfully generated embedding with its document ID
                  if final_emb is not None:
                      embeddings_to_update_in_batch.append((doc_id, final_emb.tolist()))

              # Prepare bulk operations for updating documents that had embeddings generated in this batch
              updates = []
              for doc_id, emb_list in embeddings_to_update_in_batch:
                  new_embedding_doc = {
                      'model': model_str,
                      'chunk_size': chunk_size,
                      'aggregation': agg,
                      'input': 'wiki_content_only',
                      'embedding': emb_list
                  }

                  updates.append(
                      pymongo.UpdateOne(
                          {'_id': doc_id},
                          {'$push': {'embeddings': new_embedding_doc}}
                      )
                  )

              if updates:
                  collection.bulk_write(updates)
                  print(f"  [OK] Updated {len(updates)} docs "
                        f"model={model_str}, chunk={chunk_size}, agg={agg} in batch {b+1}/{num_batches}.")
              else:
                  print(f"  [INFO] No documents updated for model={model_str}, chunk={chunk_size}, agg={agg} in batch {b+1}/{num_batches} (all docs in batch skipped).")

      print(f"Completed chunk_size={chunk_size}, agg={agg}")

print("ALL CHUNKED WIKIPEDIA EMBEDDINGS COMPLETED")
# Out:
# [INFO] 0 docs already processed → model=BAAI/bge-small-en-v1.5, chunk=250, agg=first
# [INFO] 996 docs remaining → model=BAAI/bge-small-en-v1.5, chunk=250, agg=first
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 1/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 2/100.
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 3/100
#   [OK] Updated 9 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 3/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 4/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 5/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 6/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 7/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 8/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 9/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 10/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 11/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 12/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 13/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 14/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 15/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 16/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 17/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 18/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 19/100.
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 20/100
#   [OK] Updated 9 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 20/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 21/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 22/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 23/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 24/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 25/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 26/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 27/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 28/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 29/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 30/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 31/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 32/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 33/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 34/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 35/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 36/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 37/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 38/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 39/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 40/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 41/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 42/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 43/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 44/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 45/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 46/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 47/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 48/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 49/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 50/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 51/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 52/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 53/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 54/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 55/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 56/100.
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 57/100
#   [OK] Updated 9 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 57/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 58/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 59/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 60/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 61/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 62/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 63/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 64/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 65/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 66/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 67/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 68/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 69/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 70/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 71/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 72/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 73/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 74/100.
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 75/100
#   [OK] Updated 9 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 75/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 76/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 77/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 78/100.
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 79/100
#   [OK] Updated 9 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 79/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 80/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 81/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 82/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 83/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 84/100.
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 85/100
#   [OK] Updated 9 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 85/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 86/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 87/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 88/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 89/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 90/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 91/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 92/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 93/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 94/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 95/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 96/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 97/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 98/100.
#   [OK] Updated 10 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 99/100.
#   [OK] Updated 6 docs model=BAAI/bge-small-en-v1.5, chunk=250, agg=first in batch 100/100.
# [INFO] 990 docs already processed → model=BAAI/bge-large-en-v1.5, chunk=250, agg=first
# [INFO] 6 docs remaining → model=BAAI/bge-large-en-v1.5, chunk=250, agg=first
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=first in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-large-en-v1.5, chunk=250, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=first
# [INFO] 6 docs remaining → model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=first
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=first in batch 1/1
#   [INFO] No documents updated for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic classification, chunk=250, agg=first
# [INFO] 6 docs remaining → model=nomic classification, chunk=250, agg=first
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=first in batch 1/1
#   [INFO] No documents updated for model=nomic classification, chunk=250, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic clustering, chunk=250, agg=first
# [INFO] 6 docs remaining → model=nomic clustering, chunk=250, agg=first
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=first in batch 1/1
#   [INFO] No documents updated for model=nomic clustering, chunk=250, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_query, chunk=250, agg=first
# [INFO] 6 docs remaining → model=nomic search_query, chunk=250, agg=first
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=first in batch 1/1
#   [INFO] No documents updated for model=nomic search_query, chunk=250, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_document, chunk=250, agg=first
# [INFO] 6 docs remaining → model=nomic search_document, chunk=250, agg=first
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=first in batch 1/1
#   [INFO] No documents updated for model=nomic search_document, chunk=250, agg=first in batch 1/1 (all docs in batch skipped).
# Completed chunk_size=250, agg=first
# [INFO] 990 docs already processed → model=BAAI/bge-small-en-v1.5, chunk=250, agg=mean
# [INFO] 6 docs remaining → model=BAAI/bge-small-en-v1.5, chunk=250, agg=mean
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=mean in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-small-en-v1.5, chunk=250, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=BAAI/bge-large-en-v1.5, chunk=250, agg=mean
# [INFO] 6 docs remaining → model=BAAI/bge-large-en-v1.5, chunk=250, agg=mean
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=mean in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-large-en-v1.5, chunk=250, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=mean
# [INFO] 6 docs remaining → model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=mean
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=mean in batch 1/1
#   [INFO] No documents updated for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic classification, chunk=250, agg=mean
# [INFO] 6 docs remaining → model=nomic classification, chunk=250, agg=mean
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=mean in batch 1/1
#   [INFO] No documents updated for model=nomic classification, chunk=250, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic clustering, chunk=250, agg=mean
# [INFO] 6 docs remaining → model=nomic clustering, chunk=250, agg=mean
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=mean in batch 1/1
#   [INFO] No documents updated for model=nomic clustering, chunk=250, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_query, chunk=250, agg=mean
# [INFO] 6 docs remaining → model=nomic search_query, chunk=250, agg=mean
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=mean in batch 1/1
#   [INFO] No documents updated for model=nomic search_query, chunk=250, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_document, chunk=250, agg=mean
# [INFO] 6 docs remaining → model=nomic search_document, chunk=250, agg=mean
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=mean in batch 1/1
#   [INFO] No documents updated for model=nomic search_document, chunk=250, agg=mean in batch 1/1 (all docs in batch skipped).
# Completed chunk_size=250, agg=mean
# [INFO] 990 docs already processed → model=BAAI/bge-small-en-v1.5, chunk=250, agg=exponential
# [INFO] 6 docs remaining → model=BAAI/bge-small-en-v1.5, chunk=250, agg=exponential
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=250, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-small-en-v1.5, chunk=250, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=BAAI/bge-large-en-v1.5, chunk=250, agg=exponential
# [INFO] 6 docs remaining → model=BAAI/bge-large-en-v1.5, chunk=250, agg=exponential
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=250, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-large-en-v1.5, chunk=250, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=exponential
# [INFO] 6 docs remaining → model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=exponential
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=sentence-transformers/all-mpnet-base-v2, chunk=250, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic classification, chunk=250, agg=exponential
# [INFO] 6 docs remaining → model=nomic classification, chunk=250, agg=exponential
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic classification, chunk=250, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=nomic classification, chunk=250, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic clustering, chunk=250, agg=exponential
# [INFO] 6 docs remaining → model=nomic clustering, chunk=250, agg=exponential
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic clustering, chunk=250, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=nomic clustering, chunk=250, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_query, chunk=250, agg=exponential
# [INFO] 6 docs remaining → model=nomic search_query, chunk=250, agg=exponential
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_query, chunk=250, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=nomic search_query, chunk=250, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_document, chunk=250, agg=exponential
# [INFO] 6 docs remaining → model=nomic search_document, chunk=250, agg=exponential
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_document, chunk=250, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=nomic search_document, chunk=250, agg=exponential in batch 1/1 (all docs in batch skipped).
# Completed chunk_size=250, agg=exponential
# [INFO] 990 docs already processed → model=BAAI/bge-small-en-v1.5, chunk=500, agg=first
# [INFO] 6 docs remaining → model=BAAI/bge-small-en-v1.5, chunk=500, agg=first
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=first in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-small-en-v1.5, chunk=500, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=BAAI/bge-large-en-v1.5, chunk=500, agg=first
# [INFO] 6 docs remaining → model=BAAI/bge-large-en-v1.5, chunk=500, agg=first
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=first in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-large-en-v1.5, chunk=500, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=sentence-transformers/all-mpnet-base-v2, chunk=500, agg=first
# [INFO] 6 docs remaining → model=sentence-transformers/all-mpnet-base-v2, chunk=500, agg=first
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=500, agg=first in batch 1/1
#   [INFO] No documents updated for model=sentence-transformers/all-mpnet-base-v2, chunk=500, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic classification, chunk=500, agg=first
# [INFO] 6 docs remaining → model=nomic classification, chunk=500, agg=first
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic classification, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic classification, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic classification, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic classification, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic classification, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic classification, chunk=500, agg=first in batch 1/1
#   [INFO] No documents updated for model=nomic classification, chunk=500, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic clustering, chunk=500, agg=first
# [INFO] 6 docs remaining → model=nomic clustering, chunk=500, agg=first
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic clustering, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic clustering, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic clustering, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic clustering, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic clustering, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic clustering, chunk=500, agg=first in batch 1/1
#   [INFO] No documents updated for model=nomic clustering, chunk=500, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_query, chunk=500, agg=first
# [INFO] 6 docs remaining → model=nomic search_query, chunk=500, agg=first
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_query, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_query, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_query, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_query, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_query, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_query, chunk=500, agg=first in batch 1/1
#   [INFO] No documents updated for model=nomic search_query, chunk=500, agg=first in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_document, chunk=500, agg=first
# [INFO] 6 docs remaining → model=nomic search_document, chunk=500, agg=first
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_document, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_document, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_document, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_document, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_document, chunk=500, agg=first in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_document, chunk=500, agg=first in batch 1/1
#   [INFO] No documents updated for model=nomic search_document, chunk=500, agg=first in batch 1/1 (all docs in batch skipped).
# Completed chunk_size=500, agg=first
# [INFO] 990 docs already processed → model=BAAI/bge-small-en-v1.5, chunk=500, agg=mean
# [INFO] 6 docs remaining → model=BAAI/bge-small-en-v1.5, chunk=500, agg=mean
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=500, agg=mean in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-small-en-v1.5, chunk=500, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=BAAI/bge-large-en-v1.5, chunk=500, agg=mean
# [INFO] 6 docs remaining → model=BAAI/bge-large-en-v1.5, chunk=500, agg=mean
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=500, agg=mean in batch 1/1
# ...
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=mean in batch 1/1
#   [INFO] No documents updated for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic classification, chunk=1000, agg=mean
# [INFO] 6 docs remaining → model=nomic classification, chunk=1000, agg=mean
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=mean in batch 1/1
#   [INFO] No documents updated for model=nomic classification, chunk=1000, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic clustering, chunk=1000, agg=mean
# [INFO] 6 docs remaining → model=nomic clustering, chunk=1000, agg=mean
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=mean in batch 1/1
#   [INFO] No documents updated for model=nomic clustering, chunk=1000, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_query, chunk=1000, agg=mean
# [INFO] 6 docs remaining → model=nomic search_query, chunk=1000, agg=mean
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=mean in batch 1/1
#   [INFO] No documents updated for model=nomic search_query, chunk=1000, agg=mean in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_document, chunk=1000, agg=mean
# [INFO] 6 docs remaining → model=nomic search_document, chunk=1000, agg=mean
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=mean in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=mean in batch 1/1
#   [INFO] No documents updated for model=nomic search_document, chunk=1000, agg=mean in batch 1/1 (all docs in batch skipped).
# Completed chunk_size=1000, agg=mean
# [INFO] 990 docs already processed → model=BAAI/bge-small-en-v1.5, chunk=1000, agg=exponential
# [INFO] 6 docs remaining → model=BAAI/bge-small-en-v1.5, chunk=1000, agg=exponential
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-small-en-v1.5, chunk=1000, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-small-en-v1.5, chunk=1000, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=BAAI/bge-large-en-v1.5, chunk=1000, agg=exponential
# [INFO] 6 docs remaining → model=BAAI/bge-large-en-v1.5, chunk=1000, agg=exponential
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=BAAI/bge-large-en-v1.5, chunk=1000, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=BAAI/bge-large-en-v1.5, chunk=1000, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=exponential
# [INFO] 6 docs remaining → model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=exponential
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=sentence-transformers/all-mpnet-base-v2, chunk=1000, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic classification, chunk=1000, agg=exponential
# [INFO] 6 docs remaining → model=nomic classification, chunk=1000, agg=exponential
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic classification, chunk=1000, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=nomic classification, chunk=1000, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic clustering, chunk=1000, agg=exponential
# [INFO] 6 docs remaining → model=nomic clustering, chunk=1000, agg=exponential
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic clustering, chunk=1000, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=nomic clustering, chunk=1000, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_query, chunk=1000, agg=exponential
# [INFO] 6 docs remaining → model=nomic search_query, chunk=1000, agg=exponential
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_query, chunk=1000, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=nomic search_query, chunk=1000, agg=exponential in batch 1/1 (all docs in batch skipped).
# [INFO] 990 docs already processed → model=nomic search_document, chunk=1000, agg=exponential
# [INFO] 6 docs remaining → model=nomic search_document, chunk=1000, agg=exponential
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# [WARNING] Skipping document 690c2f0530de78ca9390a990 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ab30 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390acf9 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad58 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad62 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=exponential in batch 1/1
# [WARNING] Skipping document 690c2f0530de78ca9390ad69 (empty/short 'wiki_content') for model=nomic search_document, chunk=1000, agg=exponential in batch 1/1
#   [INFO] No documents updated for model=nomic search_document, chunk=1000, agg=exponential in batch 1/1 (all docs in batch skipped).
# Completed chunk_size=1000, agg=exponential
# ALL CHUNKED WIKIPEDIA EMBEDDINGS COMPLETED

# %% [markdown]
# #### Silhouette Scores

# %% [markdown]
# ##### 250

# %%
wiki_content_250_first_silhouette = pd.Series(dtype=float)

for model_str in embeddings_lst:
  embedding_config_for_query = {
      'model': model_str,
      'chunk_size': 250,
      'aggregation': 'first',
      'input': 'wiki_content_only'
  }

  # Filter directly in MongoDB to only get documents that have the matching embedding
  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))

  if tmpdf.empty:
      print(f"No documents found with embeddings matching config for model: {model_str}, chunk_size: 250, aggregation: first. Skipping.")
      wiki_content_250_first_silhouette[model_str] = np.nan
      continue

  # At this point, tmpdf is guaranteed to have an 'embeddings' column with non-empty lists
  embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  labels = tmpdf.sector # Get labels directly from tmpdf
  wiki_content_250_first_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (WIKI CONTENT ONLY, 250 FIRST)")
display(wiki_content_250_first_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY, 250 FIRST)
# BAAI/bge-small-en-v1.5                     0.034055
# BAAI/bge-large-en-v1.5                     0.029494
# sentence-transformers/all-mpnet-base-v2    0.026920
# nomic classification                       0.048073
# nomic clustering                           0.044128
# nomic search_query                         0.035485
# nomic search_document                      0.028377
# dtype: float64

# %%
wiki_content_250_mean_silhouette = pd.Series(dtype=float)
for model_str in embeddings_lst:
  embedding_config_for_query = {
      'model': model_str,
      'chunk_size': 250,
      'aggregation': 'mean',
      'input': 'wiki_content_only'
  }

  # Filter directly in MongoDB to only get documents that have the matching embedding
  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))

  if tmpdf.empty:
      print(f"No documents found with embeddings matching config for model: {model_str}, chunk_size: 250, aggregation: mean. Skipping.")
      wiki_content_250_mean_silhouette[model_str] = np.nan
      continue
  embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  labels = tmpdf.sector # Get labels directly from tmpdf
  wiki_content_250_mean_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (WIKI CONTENT ONLY, 250 MEAN)")
display(wiki_content_250_mean_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY, 250 MEAN)
# BAAI/bge-small-en-v1.5                     0.058719
# BAAI/bge-large-en-v1.5                     0.057649
# sentence-transformers/all-mpnet-base-v2    0.061963
# nomic classification                       0.066378
# nomic clustering                           0.065715
# nomic search_query                         0.048922
# nomic search_document                      0.042925
# dtype: float64

# %%
wiki_content_250_exp_silhouette = pd.Series(dtype=float)
for model_str in embeddings_lst:
  embedding_config_for_query = {
      'model': model_str,
      'chunk_size': 250,
      'aggregation': 'exponential',
      'input': 'wiki_content_only'
  }

  # Filter directly in MongoDB to only get documents that have the matching embedding
  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))

  if tmpdf.empty:
      print(f"No documents found with embeddings matching config for model: {model_str}, chunk_size: 250, aggregation: exponential. Skipping.")
      wiki_content_250_exp_silhouette[model_str] = np.nan
      continue
  embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  labels = tmpdf.sector # Get labels directly from tmpdf
  wiki_content_250_exp_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (WIKI CONTENT ONLY, 250 EXPONENTIAL)")
display(wiki_content_250_exp_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY, 250 EXPONENTIAL)
# BAAI/bge-small-en-v1.5                     0.047362
# BAAI/bge-large-en-v1.5                     0.051567
# sentence-transformers/all-mpnet-base-v2    0.046467
# nomic classification                       0.060881
# nomic clustering                           0.054726
# nomic search_query                         0.045343
# nomic search_document                      0.042090
# dtype: float64

# %% [markdown]
# ##### 500

# %%
wiki_content_500_first_silhouette = pd.Series(dtype=float)
for model_str in embeddings_lst:
  embedding_config_for_query = {
      'model': model_str,
      'chunk_size': 500,
      'aggregation': 'first',
      'input': 'wiki_content_only'
  }

  # Filter directly in MongoDB to only get documents that have the matching embedding
  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))

  if tmpdf.empty:
      print(f"No documents found with embeddings matching config for model: {model_str}, chunk_size: 500, aggregation: first. Skipping.")
      wiki_content_500_first_silhouette[model_str] = np.nan
      continue

  embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  labels = tmpdf.sector
  wiki_content_500_first_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (WIKI CONTENT ONLY, 500 FIRST)")
display(wiki_content_500_first_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY, 500 FIRST)
# BAAI/bge-small-en-v1.5                     0.036323
# BAAI/bge-large-en-v1.5                     0.031072
# sentence-transformers/all-mpnet-base-v2    0.034081
# nomic classification                       0.051212
# nomic clustering                           0.045938
# nomic search_query                         0.037133
# nomic search_document                      0.031377
# dtype: float64

# %%
wiki_content_500_mean_silhouette = pd.Series(dtype=float)
for model_str in embeddings_lst:
  embedding_config_for_query = {
      'model': model_str,
      'chunk_size': 500,
      'aggregation': 'mean',
      'input': 'wiki_content_only'
  }

  # Filter directly in MongoDB to only get documents that have the matching embedding
  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))

  if tmpdf.empty:
      print(f"No documents found with embeddings matching config for model: {model_str}, chunk_size: 500, aggregation: mean. Skipping.")
      wiki_content_500_mean_silhouette[model_str] = np.nan
      continue
  embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  labels = tmpdf.sector
  wiki_content_500_mean_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (WIKI CONTENT ONLY, 500 MEAN)")
display(wiki_content_500_mean_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY, 500 MEAN)
# BAAI/bge-small-en-v1.5                     0.050579
# BAAI/bge-large-en-v1.5                     0.045375
# sentence-transformers/all-mpnet-base-v2    0.055709
# nomic classification                       0.060139
# nomic clustering                           0.058488
# nomic search_query                         0.041800
# nomic search_document                      0.035415
# dtype: float64

# %%
wiki_content_500_exp_silhouette = pd.Series(dtype=float)
for model_str in embeddings_lst:
  embedding_config_for_query = {
      'model': model_str,
      'chunk_size': 500,
      'aggregation': 'exponential',
      'input': 'wiki_content_only'
  }

  # Filter directly in MongoDB to only get documents that have the matching embedding
  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))

  if tmpdf.empty:
      print(f"No documents found with embeddings matching config for model: {model_str}, chunk_size: 500, aggregation: exponential. Skipping.")
      wiki_content_500_exp_silhouette[model_str] = np.nan
      continue

  embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  labels = tmpdf.sector
  wiki_content_500_exp_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (WIKI CONTENT ONLY, 500 EXPONENTIAL)")
display(wiki_content_500_exp_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY, 500 EXPONENTIAL)
# BAAI/bge-small-en-v1.5                     0.050550
# BAAI/bge-large-en-v1.5                     0.050144
# sentence-transformers/all-mpnet-base-v2    0.046303
# nomic classification                       0.059528
# nomic clustering                           0.053448
# nomic search_query                         0.043428
# nomic search_document                      0.040955
# dtype: float64

# %% [markdown]
# ##### 1000

# %%
wiki_content_1000_first_silhouette = pd.Series(dtype=float)
for model_str in embeddings_lst:
  embedding_config_for_query = {
    'model': model_str,
    'chunk_size': 1000,
    'aggregation': 'first',
    'input': 'wiki_content_only'
  }

  # Filter directly in MongoDB to only get documents that have the matching embedding
  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))

  if tmpdf.empty:
      print(f"No documents found with embeddings matching config for model: {model_str}, chunk_size: 1000, aggregation: first. Skipping.")
      wiki_content_1000_first_silhouette[model_str] = np.nan
      continue
  embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  labels = tmpdf.sector
  wiki_content_1000_first_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (WIKI CONTENT ONLY, 1000 FIRST)")
display(wiki_content_1000_first_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY, 1000 FIRST)
# BAAI/bge-small-en-v1.5                     0.036394
# BAAI/bge-large-en-v1.5                     0.033023
# sentence-transformers/all-mpnet-base-v2    0.042382
# nomic classification                       0.051027
# nomic clustering                           0.047140
# nomic search_query                         0.035564
# nomic search_document                      0.030649
# dtype: float64

# %%
wiki_content_1000_mean_silhouette = pd.Series(dtype=float)
for model_str in embeddings_lst:
  embedding_config_for_query = {
    'model': model_str,
    'chunk_size': 1000,
    'aggregation': 'mean',
    'input': 'wiki_content_only'
  }

  # Filter directly in MongoDB to only get documents that have the matching embedding
  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))

  if tmpdf.empty:
      print(f"No documents found with embeddings matching config for model: {model_str}, chunk_size: 1000, aggregation: mean. Skipping.")
      wiki_content_1000_mean_silhouette[model_str] = np.nan
      continue
  embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  labels = tmpdf.sector
  wiki_content_1000_mean_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (WIKI CONTENT ONLY, 1000 MEAN)")
display(wiki_content_1000_mean_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY, 1000 MEAN)
# BAAI/bge-small-en-v1.5                     0.040809
# BAAI/bge-large-en-v1.5                     0.027927
# sentence-transformers/all-mpnet-base-v2    0.054709
# nomic classification                       0.056935
# nomic clustering                           0.055569
# nomic search_query                         0.036247
# nomic search_document                      0.028563
# dtype: float64

# %%
wiki_content_1000_exp_silhouette = pd.Series(dtype=float)
for model_str in embeddings_lst:
  embedding_config_for_query = {
    'model': model_str,
    'chunk_size': 1000,
    'aggregation': 'exponential',
    'input': 'wiki_content_only'
  }

  # Filter directly in MongoDB to only get documents that have the matching embedding
  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))

  if tmpdf.empty:
      print(f"No documents found with embeddings matching config for model: {model_str}, chunk_size: 1000, aggregation: exponential. Skipping.")
      wiki_content_1000_exp_silhouette[model_str] = np.nan
      continue
  embedding_array = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  labels = tmpdf.sector
  wiki_content_1000_exp_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (WIKI CONTENT ONLY, 1000 EXPONENTIAL)")
display(wiki_content_1000_exp_silhouette)
# Out:
# SILHOUETTE SCORES (WIKI CONTENT ONLY, 1000 EXPONENTIAL)
# BAAI/bge-small-en-v1.5                     0.050731
# BAAI/bge-large-en-v1.5                     0.041710
# sentence-transformers/all-mpnet-base-v2    0.050200
# nomic classification                       0.057298
# nomic clustering                           0.053967
# nomic search_query                         0.039956
# nomic search_document                      0.036258
# dtype: float64

# %% [markdown]
# ### Summary and V-Card

# %%
for model_str in embeddings_lst:
  embedding_config = {
    'model': model_str,
    'chunk_size': None,
    'aggregation': None,
    'input': 'SUMMARY_andEXTRA' # <-- Key for this pipeline
    }

  has_embedding_cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config } },
    { "_id": 1 }  # Only fetch the _id
  )
  # Create a set of _id's to ignore
  has_embedding_ids = {doc['_id'] for doc in has_embedding_cursor}
  print(f"Found {len(has_embedding_ids)} documents that already have this config for model: {model_str}.")

  # --- STEP 2: Find all docs *NOT IN* that set (this is your to-do list) ---
  needs_embedding_filter = {
    "_id": {"$nin": list(has_embedding_ids)}
  }
  # Fetch the documents that need processing
  # We exclude 'embeddings' from the projection to save memory
  cursor = collection.find(
    needs_embedding_filter,
    { 'SUMMARY_business_description':1, 'SUMMARY_investment_exposure':1,
    'SUMMARY_investment_industry':1, 'SUMMARY_material_points':1,'wiki_vcard':1} # Only fetch summary and _id
  )

  todo_df = pd.DataFrame(list(cursor))
  print(f"Found {len(todo_df)} documents to process for model: {model_str}.")

  if todo_df.empty:
      print(f"No documents to process for model: {model_str}. Skipping.\n")
      continue

  # Doing the embedding - This part must be inside the loop
  if 'nomic' in model_str:
    # Load the one base model
    model = SentenceTransformer(
        'nomic-ai/nomic-embed-text-v1.5', trust_remote_code=True
    )
    # Get the prefix (e.g., "classification:")
    prefix = model_str.split()[1] + ' ' # Don't forget the space!
  else:
    model = SentenceTransformer(
        model_str, trust_remote_code=True
    )

  # Chunks by 10
  num_chunks = (len(todo_df) + 9) // 10 # ceil division
  print(f"Processing {len(todo_df)} documents in {num_chunks} chunks...")

  for i in range(num_chunks):
    start_index = i * 10
    end_index = min((i + 1) * 10, len(todo_df))
    batch_df =  todo_df.iloc[start_index:end_index] # Use iloc for integer-location based indexing

    summary_fields = [
    'SUMMARY_business_description', 'SUMMARY_investment_exposure',
    'SUMMARY_investment_industry', 'SUMMARY_material_points','wiki_vcard'
    ]
    contents_to_embed = [
        str(d) for d in batch_df[summary_fields].to_dict(orient='records')
    ]
    if 'nomic' in model_str:
      contents_to_embed = [prefix + str(d) for d in contents_to_embed]

    batch_embeddings = model.encode(contents_to_embed, normalize_embeddings=True)

    # Convert embeddings to list for MongoDB storage
    embeddings_list_of_lists = batch_embeddings.tolist()

    # Prepare bulk operations for updating documents
    updates = []
    for doc_id, embedding in zip(batch_df['_id'], embeddings_list_of_lists):
        new_embedding_doc = {
            'model': embedding_config['model'],
            'chunk_size': embedding_config['chunk_size'],
            'aggregation': embedding_config['aggregation'],
            'input': embedding_config['input'],
            'embedding': embedding # Store the actual embedding vector
        }
        updates.append(
            pymongo.UpdateOne(
                {'_id': doc_id},
                {'$push': {'embeddings': new_embedding_doc}}
            )
        )
    if updates:
        collection.bulk_write(updates)
        print(f"  Updated {len(updates)} documents with embeddings for model: {model_str} in chunk {i+1}/{num_chunks}.")
  print(f"Finished processing model: {model_str}.\n")

print("All SUMMARY embedding processed.")
# Out:
# Found 0 documents that already have this config for model: BAAI/bge-small-en-v1.5.
# Found 996 documents to process for model: BAAI/bge-small-en-v1.5.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: BAAI/bge-small-en-v1.5 in chunk
100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 83/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 84/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 85/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 86/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 87/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 88/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 89/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 90/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 91/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 92/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 93/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 94/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 95/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 96/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 97/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 98/100.
#   Updated 10 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 99/100.
#   Updated 6 documents with embeddings for model: sentence-transformers/all-mpnet-base-v2 in chunk 100/100.
# Finished processing model: sentence-transformers/all-mpnet-base-v2.
#
# Found 0 documents that already have this config for model: nomic classification.
# Found 996 documents to process for model: nomic classification.
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic classification in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic classification in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic classification in chunk 100/100.
# Finished processing model: nomic classification.
#
# Found 0 documents that already have this config for model: nomic clustering.
# Found 996 documents to process for model: nomic clustering.
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic clustering in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic clustering in chunk 100/100.
# Finished processing model: nomic clustering.
#
# ...
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic search_query in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic search_query in chunk 100/100.
# Finished processing model: nomic search_query.
#
# Found 0 documents that already have this config for model: nomic search_document.
# Found 996 documents to process for model: nomic search_document.
# WARNING:transformers_modules.nomic_hyphen_ai.nomic_hyphen_bert_hyphen_2048.7710840340a098cfb869c4f65e87cf2b1b70caca.modeling_hf_nomic_bert:<All keys matched successfully>
# Processing 996 documents in 100 chunks...
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 1/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 2/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 3/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 4/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 5/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 6/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 7/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 8/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 9/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 10/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 11/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 12/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 13/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 14/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 15/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 16/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 17/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 18/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 19/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 20/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 21/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 22/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 23/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 24/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 25/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 26/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 27/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 28/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 29/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 30/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 31/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 32/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 33/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 34/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 35/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 36/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 37/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 38/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 39/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 40/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 41/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 42/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 43/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 44/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 45/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 46/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 47/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 48/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 49/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 50/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 51/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 52/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 53/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 54/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 55/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 56/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 57/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 58/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 59/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 60/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 61/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 62/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 63/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 64/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 65/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 66/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 67/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 68/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 69/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 70/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 71/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 72/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 73/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 74/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 75/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 76/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 77/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 78/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 79/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 80/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 81/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 82/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 83/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 84/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 85/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 86/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 87/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 88/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 89/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 90/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 91/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 92/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 93/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 94/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 95/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 96/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 97/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 98/100.
#   Updated 10 documents with embeddings for model: nomic search_document in chunk 99/100.
#   Updated 6 documents with embeddings for model: nomic search_document in chunk 100/100.
# Finished processing model: nomic search_document.
#
# All SUMMARY embedding processed.

# %%
summary_plus_silhouette = pd.Series(dtype=float)

for model_str in embeddings_lst:

    tmpdf = pd.DataFrame(collection.find(
        {},
        {
            'ticker':1,
            'sector': 1,
            'embeddings': {
                '$elemMatch': {
                    'model': model_str,
                    'chunk_size': None,
                    'aggregation': None,
                    'input': 'SUMMARY_andEXTRA'
                }
            }
        }
    ))

    tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]

    if len(tmpdf) == 0:
        print(f"No SUMMARY_andEXTRA embeddings for {model_str}")
        summary_plus_silhouette[model_str] = np.nan
        continue

    embedding_array = np.array([emb[0]['embedding'] for emb in tmpdf.embeddings])
    labels = tmpdf['sector']

    summary_plus_silhouette[model_str] = silhouette_score(embedding_array, labels, metric='cosine')

print("SILHOUETTE SCORES (SUMMARY AND VCARD)")
display(summary_plus_silhouette)
# Out:
# SILHOUETTE SCORES (SUMMARY AND VCARD)
# BAAI/bge-small-en-v1.5                     0.041428
# BAAI/bge-large-en-v1.5                     0.051380
# sentence-transformers/all-mpnet-base-v2    0.049855
# nomic classification                       0.081591
# nomic clustering                           0.069737
# nomic search_query                         0.057699
# nomic search_document                      0.048393
# dtype: float64

# %% [markdown]
# ##### Comparison

# %%
comparison_df = pd.concat([wiki_content_only_silhouette,summary_only_silhouette,wiki_content_250_first_silhouette,wiki_content_250_mean_silhouette,wiki_content_250_exp_silhouette,
                           wiki_content_500_first_silhouette,wiki_content_500_mean_silhouette,wiki_content_500_exp_silhouette,wiki_content_1000_first_silhouette,
                           wiki_content_1000_mean_silhouette, wiki_content_1000_exp_silhouette,summary_plus_silhouette],axis=1)
comparison_df.columns = ['wiki_content_only','summary_only','wiki_content_250_first', 'wiki_content_250_mean','wiki_content_250_exp','wiki_content_500_first',
                         'wiki_content_500_mean','wiki_content_500_exp','wiki_content_1000_first','wiki_content_1000_mean',
                         'wiki_content_1000_exp','summary_plus']
display(comparison_df)
# Out:
#                                          wiki_content_only  summary_only  \
# BAAI/bge-small-en-v1.5                            0.036841      0.041492
# BAAI/bge-large-en-v1.5                            0.037180      0.045772
# sentence-transformers/all-mpnet-base-v2           0.045547      0.045070
# nomic classification                             -0.007615      0.077546
# nomic clustering                                 -0.018137      0.068625
# nomic search_query                               -0.021351      0.054863
# nomic search_document                            -0.019547      0.047128
#
#                                          wiki_content_250_first  \
# BAAI/bge-small-en-v1.5                                 0.034055
# BAAI/bge-large-en-v1.5                                 0.029494
# sentence-transformers/all-mpnet-base-v2                0.026920
# nomic classification                                   0.048073
# nomic clustering                                       0.044128
# nomic search_query                                     0.035485
# nomic search_document                                  0.028377
#
#                                          wiki_content_250_mean  \
# BAAI/bge-small-en-v1.5                                0.058719
# BAAI/bge-large-en-v1.5                                0.057649
# sentence-transformers/all-mpnet-base-v2               0.061963
# nomic classification                                  0.066378
# nomic clustering                                      0.065715
# nomic search_query                                    0.048922
# nomic search_document                                 0.042925
#
#                                          wiki_content_250_exp  \
# BAAI/bge-small-en-v1.5                               0.047362
# BAAI/bge-large-en-v1.5                               0.051567
# sentence-transformers/all-mpnet-base-v2              0.046467
# nomic classification                                 0.060881
# nomic clustering                                     0.054726
# nomic search_query                                   0.045343
# nomic search_document                                0.042090
#
#                                          wiki_content_500_first  \
# BAAI/bge-small-en-v1.5                                 0.036323
# BAAI/bge-large-en-v1.5                                 0.031072
# sentence-transformers/all-mpnet-base-v2                0.034081
# nomic classification                                   0.051212
# nomic clustering                                       0.045938
# nomic search_query                                     0.037133
# nomic search_document                                  0.031377
#
#                                          wiki_content_500_mean  \
# BAAI/bge-small-en-v1.5                                0.050579
# BAAI/bge-large-en-v1.5                                0.045375
# sentence-transformers/all-mpnet-base-v2               0.055709
# nomic classification                                  0.060139
# nomic clustering                                      0.058488
# nomic search_query                                    0.041800
# nomic search_document                                 0.035415
#
#                                          wiki_content_500_exp  \
# BAAI/bge-small-en-v1.5                               0.050550
# BAAI/bge-large-en-v1.5                               0.050144
# sentence-transformers/all-mpnet-base-v2              0.046303
# nomic classification                                 0.059528
# nomic clustering                                     0.053448
# nomic search_query                                   0.043428
# nomic search_document                                0.040955
#
#                                          wiki_content_1000_first  \
# BAAI/bge-small-en-v1.5                                  0.036394
# BAAI/bge-large-en-v1.5                                  0.033023
# sentence-transformers/all-mpnet-base-v2                 0.042382
# nomic classification                                    0.051027
# nomic clustering                                        0.047140
# nomic search_query                                      0.035564
# nomic search_document                                   0.030649
#
#                                          wiki_content_1000_mean  \
# BAAI/bge-small-en-v1.5                                 0.040809
# BAAI/bge-large-en-v1.5                                 0.027927
# sentence-transformers/all-mpnet-base-v2                0.054709
# nomic classification                                   0.056935
# nomic clustering                                       0.055569
# nomic search_query                                     0.036247
# nomic search_document                                  0.028563
#
#                                          wiki_content_1000_exp  summary_plus
# BAAI/bge-small-en-v1.5                                0.050731      0.041428
# BAAI/bge-large-en-v1.5                                0.041710      0.051380
# sentence-transformers/all-mpnet-base-v2               0.050200      0.049855
# nomic classification                                  0.057298      0.081591
# nomic clustering                                      0.053967      0.069737
# nomic search_query                                    0.039956      0.057699
# nomic search_document                                 0.036258      0.048393

# %% [markdown]
# ### Why?
# One interesting observation from this comparison chart is how the nomic model completely breaks down for the qhole wikipedia content, but when chucking or summarizing, the model is quite capable at creating an embedding that is representative of the sector information. The most likely scenario for this is that due to it's large token limit, it falls into the "Lost in the Middle" Phenomenon, where it looks the ability to take in the context of the center of the text when doing the embedding, which has been observed in many other large language models as they try to analysis large swaths of information as if the relevant information is found within the larger text document, the data gets relatively lost when in the middle of the text versus at the ends. This phenomenon plays into the bge and mpnet models well because with their lower token limit, they embed the text using only the most recent and relevent information so that regardless of the length of the text, it stays pretty consistent to a chunking model as you can see above. However for the nomic model, because it has a larger token limit, it takes in all the information to fill that toekn limit and then uses that for the individual embeddings, which cause the entire embedding model to start crashing as only the beginning and end are seen as relevent information to the embeddings. Because of this, we can also tell that the summary field can yield high information as we know that the models can use the entire field to generate information from without losing anything to the middle signal, as long as we assume the LLM we worked with are accurate.

# %% [markdown]
# ### YFinance

# %%
import yfinance as yf
tmpdf = pd.DataFrame(collection.find(
        {},
        {
            'ticker':1,
            'sector': 1,
            }
    ))
allticker = tmpdf.ticker.tolist()
yf_df = yf.download(allticker)
# Out:
# /tmp/ipython-input-3152672601.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf_df = yf.download(allticker)
# [*********************100%***********************]  996 of 996 completed
# ERROR:yfinance:
# 5 Failed downloads:
# ERROR:yfinance:['BFA', 'HEIA', 'LENB', 'BFB', 'BRKB']: YFPricesMissingError('possibly delisted; no price data found  (period=1mo) (Yahoo error = "No data found, symbol may be delisted")')

# %%
corrmat = yf_df.Close.pct_change().clip(-0.1,0.1).corr()
corrmat
# Out:
# /tmp/ipython-input-651536451.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   corrmat = yf_df.Close.pct_change().clip(-0.1,0.1).corr()
# Ticker         A        AA       AAL      AAON      AAPL      ABBV      ABNB  \
# Ticker
# A       1.000000  0.204422  0.342501  0.337485  0.449868  0.539765  0.416571
# AA      0.204422  1.000000  0.634879  0.532810  0.165771 -0.168904  0.188621
# AAL     0.342501  0.634879  1.000000  0.545144  0.147052  0.031008  0.448874
# AAON    0.337485  0.532810  0.545144  1.000000  0.118491 -0.020879  0.294204
# AAPL    0.449868  0.165771  0.147052  0.118491  1.000000  0.071007  0.636955
# ...          ...       ...       ...       ...       ...       ...       ...
# ZG      0.588892  0.161478  0.503407  0.509308  0.519581  0.201310  0.574438
# ZION    0.482420  0.327393  0.552771  0.387684  0.532382  0.072248  0.659168
# ZM      0.388411  0.175989  0.253373  0.151990  0.314232  0.193235  0.776826
# ZS      0.366947 -0.042736 -0.070520  0.300272  0.253118  0.102713  0.389265
# ZTS     0.311722  0.402124  0.521915  0.372720  0.256473  0.067035  0.692299
#
# Ticker       ABT      ACGL      ACHC  ...      YETI       YUM         Z  \
# Ticker                                ...
# A       0.398984  0.263391  0.561166  ...  0.584306  0.388170  0.612251
# AA      0.018362 -0.034974  0.189427  ...  0.397145 -0.437046  0.189829
# AAL     0.155530  0.157609  0.492902  ...  0.533840 -0.188500  0.504472
# AAON   -0.029179 -0.106962  0.278581  ...  0.666419 -0.340037  0.478038
# AAPL    0.221259 -0.075545  0.387630  ...  0.632607  0.155045  0.545055
# ...          ...       ...       ...  ...       ...       ...       ...
# ZG      0.287630  0.088928  0.601914  ...  0.706915  0.147803  0.990700
# ZION    0.118413  0.190509  0.375088  ...  0.608036  0.158076  0.607730
# ZM      0.162186  0.255684  0.406740  ...  0.457507  0.023080  0.451362
# ZS     -0.067363 -0.018817 -0.025692  ...  0.307716  0.064360  0.350942
# ZTS     0.223414 -0.002205  0.434127  ...  0.594258 -0.425744  0.607198
#
# Ticker       ZBH      ZBRA        ZG      ZION        ZM        ZS       ZTS
# Ticker
# A       0.349737  0.581953  0.588892  0.482420  0.388411  0.366947  0.311722
# AA      0.081878  0.546885  0.161478  0.327393  0.175989 -0.042736  0.402124
# AAL    -0.207740  0.808475  0.503407  0.552771  0.253373 -0.070520  0.521915
# AAON   -0.180012  0.529198  0.509308  0.387684  0.151990  0.300272  0.372720
# AAPL    0.158561  0.374367  0.519581  0.532382  0.314232  0.253118  0.256473
# ...          ...       ...       ...       ...       ...       ...       ...
# ZG      0.190943  0.684488  1.000000  0.571963  0.363650  0.323954  0.590125
# ZION    0.102493  0.765499  0.571963  1.000000  0.480997  0.235531  0.416655
# ZM      0.228464  0.457543  0.363650  0.480997  1.000000  0.582763  0.543623
# ZS      0.105220  0.183430  0.323954  0.235531  0.582763  1.000000  0.200553
# ZTS     0.249114  0.586780  0.590125  0.416655  0.543623  0.200553  1.000000
#
# [996 rows x 996 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

def precision_recall_at_k(embedding_matrix, corrmat, k_values=[5, 10, 20, 25, 50]):
    """
    Calculates precision@k and recall@k for all tickers.

    Parameters:
    - embedding_matrix: (n_samples, n_features) numpy array of embeddings
    - corrmat: (n_samples, n_samples) pandas DataFrame of price correlations.
               IMPORTANT: Must be in the same ticker order as the embedding_matrix.
    - k_values: List of integers for k.
    """

    # Calculate semantic similarity
    embedding_sim = cosine_similarity(embedding_matrix)

    results = []
    tickers = corrmat.columns

    for i, ticker in enumerate(tickers):
        ticker_results = {'ticker': ticker}

        for k in k_values:
            # Top K from correlations (ground truth)
            # [1:k+1] to exclude the item itself (corr=1.0)
            corr_top_k = set(corrmat[ticker].sort_values(ascending=False).iloc[1:k+1].index)

            # Top K from embeddings (our model's prediction)
            # [::-1][1:k+1] to sort descending and exclude self
            emb_indices = np.argsort(embedding_sim[i])[::-1][1:k+1]
            emb_top_k = set([tickers[idx] for idx in emb_indices])

            # Calculate metrics
            intersection = len(corr_top_k & emb_top_k)

            precision = intersection / k
            recall = intersection / k # k is same size for both sets
            f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

            ticker_results[f'precision@{k}'] = precision
            ticker_results[f'recall@{k}'] = recall
            ticker_results[f'f1@{k}'] = f1

        results.append(ticker_results)

    return pd.DataFrame(results)

# %% [markdown]
# With this, lets test: Full wiki content, Summary, Summary + VCard, 250+Mean, 250+Exp, 500+Mean, 1000+Exp

# %% [markdown]
# ##### Wiki Content

# %%
model_at25_wiki_results = {}
for model_str in embeddings_lst:
  tmpdf = pd.DataFrame(collection.find(
    { "wiki_content": { "$exists": True } ,
     "SUMMARY_material_points": {"$exists":True}},
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': {
                'model': model_str,
                'chunk_size': None,
                'aggregation': None,
                'input': 'wiki_content_only'
            }
        }}))
  tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]
  this_embedding = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  results_df = precision_recall_at_k(this_embedding, corrmat.loc[tmpdf.ticker,tmpdf.ticker],k_values=[5, 10, 20, 25, 50])
  model_at25_wiki_results[model_str] = results_df['precision@25'].mean()

model_at25_wiki = pd.Series(model_at25_wiki_results)
print('Completed for Wiki_Content')
# Out:
# Completed for Wiki_Content

# %% [markdown]
# ##### Summary

# %%
model_at25_sum_results = {}
for model_str in embeddings_lst:
  tmpdf = pd.DataFrame(collection.find(
    { "wiki_content": { "$exists": True } ,
     "SUMMARY_material_points": {"$exists":True}},
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': {
                'model': model_str,
                'chunk_size': None,
                'aggregation': None,
                'input': 'SUMMARY_only'
            }
        }}))
  tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]
  this_embedding = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  results_df = precision_recall_at_k(this_embedding, corrmat.loc[tmpdf.ticker,tmpdf.ticker],k_values=[5, 10, 20, 25, 50])
  model_at25_sum_results[model_str] = results_df['precision@25'].mean()

model_at25_sum = pd.Series(model_at25_sum_results)
print('Completed for SUMMARY_Content')
# Out:
# Completed for SUMMARY_Content

# %% [markdown]
# ##### Summary + VCard

# %%
model_at25_sumex_results = {}
for model_str in embeddings_lst:
  tmpdf = pd.DataFrame(collection.find(
    { "wiki_content": { "$exists": True } ,
     "SUMMARY_material_points": {"$exists":True}},
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': {
                'model': model_str,
                'chunk_size': None,
                'aggregation': None,
                'input': 'SUMMARY_andEXTRA'
            }
        }}))
  tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]
  this_embedding = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  results_df = precision_recall_at_k(this_embedding, corrmat.loc[tmpdf.ticker,tmpdf.ticker],k_values=[5, 10, 20, 25, 50])
  model_at25_sumex_results[model_str] = results_df['precision@25'].mean()

model_at25_sumex = pd.Series(model_at25_sumex_results)
print('Completed for SUMMARY_and_EXTRA')
# Out:
# Completed for SUMMARY_and_EXTRA

# %% [markdown]
# ##### Wiki Content, 250+Mean

# %%
model_at25_wiki_250_mean_results = {}
for model_str in embeddings_lst:
  embedding_config_for_query = {
      'model': model_str,
      'chunk_size': 250,
      'aggregation': "mean",
      'input': 'wiki_content_only'
  }

  cursor = collection.find(
    { "embeddings": { "$elemMatch": embedding_config_for_query } },
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    })

  tmpdf = pd.DataFrame(list(cursor))


  if tmpdf.empty or 'embeddings' not in tmpdf.columns or tmpdf['embeddings'].isnull().all():
      print(f"No documents with valid embeddings found for {model_str} with chunk_size 250 and aggregation mean. Skipping.")
      model_at25_wiki_250_mean_results[model_str] = np.nan
      continue

  tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]
  this_embedding = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  results_df = precision_recall_at_k(this_embedding, corrmat.loc[tmpdf.ticker,tmpdf.ticker],k_values=[5, 10, 20, 25, 50])
  model_at25_wiki_250_mean_results[model_str] = results_df['precision@25'].mean()

model_at25_wiki_250_mean = pd.Series(model_at25_wiki_250_mean_results)
print('Completed for Wiki_Content, 250+Mean')
# Out:
# Completed for Wiki_Content, 250+Mean

# %% [markdown]
# ##### Wiki Content, 250+Exp

# %%
model_at25_wiki_250_exp_results = {}
for model_str in embeddings_lst:
  embedding_config_for_query = {
      'model': model_str,
      'chunk_size': 250,
      'aggregation': "exponential",
      'input': 'wiki_content_only'
  }

  tmpdf = pd.DataFrame(collection.find(
    { "wiki_content": { "$exists": True } ,
     "SUMMARY_material_points": {"$exists":True}},
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': embedding_config_for_query
        }
    }))

  if tmpdf.empty or 'embeddings' not in tmpdf.columns or tmpdf['embeddings'].isnull().all():
      print(f"No documents with valid embeddings found for {model_str} with chunk_size 250 and aggregation exponential. Skipping.")
      model_at25_wiki_250_exp_results[model_str] = np.nan
      continue

  tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]
  this_embedding = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  results_df = precision_recall_at_k(this_embedding, corrmat.loc[tmpdf.ticker,tmpdf.ticker],k_values=[5, 10, 20, 25, 50])
  model_at25_wiki_250_exp_results[model_str] = results_df['precision@25'].mean()

model_at25_wiki_250_exp = pd.Series(model_at25_wiki_250_exp_results)
print('Completed for Wiki_Content, 250+Exp')
# Out:
# Completed for Wiki_Content, 250+Exp

# %% [markdown]
# ##### Wiki Content, 500+Mean

# %%
model_at25_wiki_500_mean_results = {}
for model_str in embeddings_lst:
  tmpdf = pd.DataFrame(collection.find(
    { "wiki_content": { "$exists": True } ,
     "SUMMARY_material_points": {"$exists":True}},
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': {
                'model': model_str,
                'chunk_size': 500,
                'aggregation': "mean",
                'input': 'wiki_content_only'
            }
        }}))

  if tmpdf.empty or 'embeddings' not in tmpdf.columns or tmpdf['embeddings'].isnull().all():
      print(f"No documents with valid embeddings found for {model_str} with chunk_size 500 and aggregation mean. Skipping.")
      model_at25_wiki_500_mean_results[model_str] = np.nan
      continue

  tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]
  this_embedding = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  results_df = precision_recall_at_k(this_embedding, corrmat.loc[tmpdf.ticker,tmpdf.ticker],k_values=[5, 10, 20, 25, 50])
  model_at25_wiki_500_mean_results[model_str] = results_df['precision@25'].mean()

model_at25_wiki_500_mean = pd.Series(model_at25_wiki_500_mean_results)
print('Completed for Wiki_Content, 500+Mean')
# Out:
# Completed for Wiki_Content, 500+Mean

# %% [markdown]
# ##### Wiki Content, 1000+Exp

# %%
model_at25_wiki_1000_exp_results = {}
for model_str in embeddings_lst:
  tmpdf = pd.DataFrame(collection.find(
    { "wiki_content": { "$exists": True } ,
     "SUMMARY_material_points": {"$exists":True}},
    {
        'ticker':1,
        'sector':1,
        'embeddings': {
            '$elemMatch': {
                'model': model_str,
                'chunk_size': 1000,
                'aggregation': "exponential",
                'input': 'wiki_content_only'
            }
        }}))

  if tmpdf.empty or 'embeddings' not in tmpdf.columns or tmpdf['embeddings'].isnull().all():
      print(f"No documents with valid embeddings found for {model_str} with chunk_size 1000 and aggregation exponential. Skipping.")
      model_at25_wiki_1000_exp_results[model_str] = np.nan
      continue

  tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]
  this_embedding = np.array(tmpdf.embeddings.map(lambda x: x[0]['embedding']).tolist())
  results_df = precision_recall_at_k(this_embedding, corrmat.loc[tmpdf.ticker,tmpdf.ticker],k_values=[5, 10, 20, 25, 50])
  model_at25_wiki_1000_exp_results[model_str] = results_df['precision@25'].mean()

model_at25_wiki_1000_exp = pd.Series(model_at25_wiki_1000_exp_results)
print('Completed for Wiki_Content, 1000+Exp')
# Out:
# Completed for Wiki_Content, 1000+Exp

# %% [markdown]
# ##### Comparison

# %%
comparison_df = pd.concat([model_at25_wiki, model_at25_sum, model_at25_wiki_250_mean, model_at25_wiki_250_exp,
                           model_at25_wiki_500_mean, model_at25_wiki_1000_exp, model_at25_sumex], axis=1)
comparison_df.columns =['wiki_content_only','summary_only', 'wiki_content_250_mean','wiki_content_250_exp',
                         'wiki_content_500_mean','wiki_content_1000_exp','summary_plus']

display(comparison_df)
# Out:
#                                          wiki_content_only  summary_only  \
# BAAI/bge-small-en-v1.5                            0.109799      0.118635
# BAAI/bge-large-en-v1.5                            0.107028      0.122169
# sentence-transformers/all-mpnet-base-v2           0.118795      0.112209
# nomic classification                              0.096506      0.138032
# nomic clustering                                  0.096185      0.132771
# nomic search_query                                0.087631      0.128193
# nomic search_document                             0.086104      0.122329
#
#                                          wiki_content_250_mean  \
# BAAI/bge-small-en-v1.5                                0.110990
# BAAI/bge-large-en-v1.5                                0.115677
# sentence-transformers/all-mpnet-base-v2               0.122424
# nomic classification                                  0.116970
# nomic clustering                                      0.117333
# nomic search_query                                    0.105293
# nomic search_document                                 0.104162
#
#                                          wiki_content_250_exp  \
# BAAI/bge-small-en-v1.5                               0.112121
# BAAI/bge-large-en-v1.5                               0.118869
# sentence-transformers/all-mpnet-base-v2              0.112121
# nomic classification                                 0.119960
# nomic clustering                                     0.115919
# nomic search_query                                   0.106303
# nomic search_document                                0.103192
#
#                                          wiki_content_500_mean  \
# BAAI/bge-small-en-v1.5                                0.111717
# BAAI/bge-large-en-v1.5                                0.112364
# sentence-transformers/all-mpnet-base-v2               0.120364
# nomic classification                                  0.115192
# nomic clustering                                      0.114828
# nomic search_query                                    0.104404
# nomic search_document                                 0.103111
#
#                                          wiki_content_1000_exp  summary_plus
# BAAI/bge-small-en-v1.5                                0.113212      0.113735
# BAAI/bge-large-en-v1.5                                0.113697      0.127309
# sentence-transformers/all-mpnet-base-v2               0.119798      0.114096
# nomic classification                                  0.121293      0.138193
# nomic clustering                                      0.118586      0.130522
# nomic search_query                                    0.107677      0.126988
# nomic search_document                                 0.105495      0.122490

# %% [markdown]
# From the YFinance data, it seems like the nomic classification on the summary and extra data still seems like the best version of the embedding, so now we are fairly confident that we can being it to production.

# %% [markdown]
# ### To Production

# %%
todo = list(collection.find({
    "embedding": {"$exists": True},
    "production_embedding":{"$exists":False}
}))
print(f"Documents to add production embeddings: {len(todo)}")
# Out:
# Documents to add production embeddings: 0

# %%
embedding_config = {
    'model': 'nomic classification',
    'chunk_size': None,
    'aggregation': None,
    'input': 'SUMMARY_andEXTRA' # Ensure this matches the desired production embedding source
}

# Retrieve documents with the specific embedding to be set as production
tmpdf = pd.DataFrame(collection.find(
    { "embeddings": { "$elemMatch": embedding_config },
     "production_embedding":{"$exists":False}},
    {
        '_id': 1,
        'embeddings': { '$elemMatch': embedding_config }
    }
))

try:
  tmpdf = tmpdf.loc[tmpdf.embeddings.notna()]

  if not tmpdf.empty:
      updates = []
      for index, row in tmpdf.iterrows():
          doc_id = row['_id']
          production_config = row['embeddings'][0]
          updates.append(
              pymongo.UpdateOne(
                  {'_id': doc_id},
                  {'$set': {'production_embedding': production_config}}
              )
          )

      if updates:
          result = collection.bulk_write(updates)
          print(f"Successfully updated {result.modified_count} documents with the production embedding.")
      else:
          print("No documents to update with production embeddings.")
  else:
    print(f"No documents found with embeddings matching the specified config for production deployment.")

except Exception as e:
    print(f"No documents found with embeddings matching the specified config for production deployment.")
# Out:
# No documents found with embeddings matching the specified config for production deployment.

# %%
# Verify a few documents to ensure the production_embedding field is set correctly
print("Verifying a few documents:")
for doc in collection.find({"production_embedding": {"$exists": True}},{"ticker":1,'name':1,'production_embedding':1}).limit(5):
    print(f"Document ID: {doc['_id']}, Production Embedding Shape: {np.array(doc['production_embedding']).shape if 'production_embedding' in doc else 'N/A'}")
    display(doc)
# Out:
# Verifying a few documents:
# Document ID: 690c2f0530de78ca9390a9cd, Production Embedding Shape: ()
# {'_id': ObjectId('690c2f0530de78ca9390a9cd'),
#  'ticker': 'ACN',
#  'name': 'ACCENTURE PLC CLASS A',
#  'production_embedding': {'model': 'nomic classification',
#   'chunk_size': None,
#   'aggregation': None,
#   'input': 'SUMMARY_andEXTRA',
#   'embedding': [-0.010781675577163696,
#    0.008578801527619362,
#    0.012419123202562332,
#    -0.05977353826165199,
#    0.012593378312885761,
#    -0.029096918180584908,
#    0.0725516676902771,
#    -0.016718152910470963,
#    -0.018517857417464256,
#    -0.013895452953875065,
#    -0.01100840512663126,
#    0.03755444660782814,
#    -0.055327158421278,
#    0.009536751545965672,
#    0.0008749010157771409,
#    -0.019462047144770622,
#    -0.014343838207423687,
#    -0.008650997653603554,
#    -0.005140630528330803,
#    -0.016608113422989845,
#    0.018562152981758118,
#    0.011224648915231228,
#    -0.0883978009223938,
#    -0.016153447329998016,
#    0.003278164193034172,
#    0.03281417861580849,
#    -0.006329428404569626,
#    -0.048364363610744476,
#    -0.010887505486607552,
#    0.018610414117574692,
#    -0.026522433385252953,
#    0.041832808405160904,
#    -0.03465768322348595,
#    -0.0015780924586579204,
#    -0.014600517228245735,
#    -0.03631218895316124,
#    -0.013147996738553047,
#    -0.0488906130194664,
#    0.062170058488845825,
#    -0.030759762972593307,
#    -0.006393337622284889,
#    -0.07541665434837341,
#    -0.02551794983446598,
#    -0.027512745931744576,
#    -0.04265368729829788,
#    -0.05691194534301758,
#    -0.007706878706812859,
#    -0.025889981538057327,
#    -0.027630027383565903,
#    -0.026861824095249176,
#    -0.03576148301362991,
#    0.016474176198244095,
#    0.03328714147210121,
#    0.0236420426517725,
#    -0.02705540880560875,
#    0.029555749148130417,
#    -0.03009476698935032,
#    -0.012711486779153347,
#    0.009322626516222954,
#    0.022804155945777893,
#    0.015278499573469162,
#    -0.0008834655163809657,
#    0.04473675787448883,
#    0.09353180974721909,
#    0.014909222722053528,
#    0.027607647702097893,
#    -0.06133081763982773,
#    0.020594263449311256,
#    -0.01071861945092678,
#    -0.024535948410630226,
#    -0.04383410885930061,
#    -0.05072338506579399,
#    -0.000546170340385288]}}

# %% [markdown]
# ### Final Analysis:
# Input Text:
# We want to use the summary text for our analysis because both the silhouette score and the yfinance analysis indicate that it produces the best overall results. We are confident that the summary provides rich information, offers sufficient context for our embedding models, and effectively distinguishes between different categories of companies. Additionally, we intend to include the extra VCard data, as it enhances the initial summary vector and improves the results across the table.
#
# Model:
# Based on the results, we have determined that the nomic-ai model is the most effective for this embedding task, as it achieves the highest classification scores in terms of silhouette and precision. Although it does experience challenges with attentiveness when processing large amounts of context data, we found that reducing text length through chunking or summarization yields the best results.
#
# Nomic Prefix:
# We have discovered that, regardless of the task, classification performs the best when input into the nomic-ai model. Therefore, we have decided to use that prefix for the remainder of our project. This is likely because the model can concentrate on creating classification buckets for organizing companies, allowing it to embed the text based on that focus rather than for simple searching. As a result, it produces the most meaningful information.

# %% [markdown]
# ### The Following is Artifacted Code
# From the inital tests before we ran out of space on the database, we were only able to get through all the 250 aggregations, and the 500-first, so to compare with all the other methods, we have the following:
# ![Initial Run.png](data:image/png;base64,...)

# %% [markdown]
# With this information, it is safe to delete the 250-first, and 250-exp, and 500-first as they are all marketly worse than the summary field. Which is what the code below would reflect that we did. However due to MongoDB not allowing for any more write commands and not being even able to edit documents directly, we had to spend money to upgrade to a Flex plan for this project. The code is left as an artifact to show what was learned on this project.

# %%
print("Starting removal of specified embedding configurations...")
unset_list = [[250,'first'],[250,'exponential'],[500,'first'],[500,'exponential'],[1000,'first'],[1000,'mean']]
for item in unset_list:
    chunk_size_to_unset = item[0]
    aggregation_to_unset = item[1]

    for model_str in embeddings_lst:
        # Define the embedding configuration to be removed
        embedding_config_to_remove = {
            'model': model_str,
            'chunk_size': chunk_size_to_unset,
            'aggregation': aggregation_to_unset,
            'input': 'wiki_content_only' # Assuming this is consistent for all unsets
        }

        has_embedding_cursor = collection.find(
              {'embeddings': {'$elemMatch': embedding_config_to_remove}},
              {'_id': 1}
          )
        existing_ids = {doc['_id'] for doc in has_embedding_cursor}
        print(f"[INFO] {len(existing_ids)} docs need to be updated for model {model_str}, chunk size {chunk_size_to_unset}, aggregation {aggregation_to_unset}")

        # Use $pull to remove elements from the 'embeddings' array that match the config
        result = collection.update_many(
            {}, # Query all documents
            { '$pull': { 'embeddings': embedding_config_to_remove } }
        )

        print(f"Removed {result.modified_count} embeddings for model: {model_str}, chunk_size: {chunk_size_to_unset}, aggregation: {aggregation_to_unset}.")

print("Finished removal of specified embedding configurations.")
# Out:
# Starting removal of specified embedding configurations...
# [INFO] 990 docs need to be updated for model BAAI/bge-small-en-v1.5, chunk size 250, aggregation first
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# /tmp/ipython-input-2733285032.py in <cell line: 0>()
#      22
#      23         # Use $pull to remove elements from the 'embeddings' array that match the config
# ---> 24         result = collection.update_many(
#      25             {}, # Query all documents
#      26             { '$pull': { 'embeddings': embedding_config_to_remove } }
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in update_many(self, filter, update, upsert, array_filters, bypass_document_validation, collation, hint, session, let, comment)
#    1435         write_concern = self._write_concern_for(session)
#    1436         return UpdateResult(
# -> 1437             self._update_retryable(
#    1438                 filter,
#    1439                 update,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in _update_retryable(self, criteria, document, operation, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, let, sort, comment)
#    1116             )
#    1117
# -> 1118         return self._database.client._retryable_write(
#    1119             (write_concern or self.write_concern).acknowledged and not multi,
#    1120             _update,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2080         """
#    2081         with self._tmp_session(session) as s:
# -> 2082             return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#    2083
#    2084     def _cleanup_cursor_no_lock(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1966             retryable and self.options.retry_writes and session and not session.in_transaction
#    1967         )
# -> 1968         return self._retry_internal(
#    1969             func=func,
#    1970             session=session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    2012             retryable=retryable,
#    2013             operation_id=operation_id,
# -> 2014         ).run()
#    2015
#    2016     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2763             self._check_last_error(check_csot=True)
#    2764             try:
# -> 2765                 return self._read() if self._is_read else self._write()
#    2766             except ServerSelectionTimeoutError:
#    2767                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _write(self)
#    2895                         operationId=self._operation_id,
#    2896                     )
# -> 2897                 return self._func(self._session, conn, self._retryable)  # type: ignore
#    2898         except PyMongoError as exc:
#    2899             if not self._retryable:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in _update(session, conn, retryable_write)
#    1096             session: Optional[ClientSession], conn: Connection, retryable_write: bool
#    1097         ) -> Optional[Mapping[str, Any]]:
# -> 1098             return self._update(
#    1099                 conn,
#    1100                 criteria,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in _update(self, conn, criteria, document, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, retryable_write, let, sort, comment)
#    1047         # so we make a shallow copy here before adding updatedExisting.
#    1048         result = (
# -> 1049             conn.command(
#    1050                 self._database.name,
#    1051                 command,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/helpers.py in inner(*args, **kwargs)
#      45
#      46         try:
# ---> 47             return func(*args, **kwargs)
#      48         except OperationFailure as exc:
#      49             if no_reauth:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411             self._raise_if_not_writable(unacknowledged)
#     412         try:
# --> 413             return command(
#     414                 self,
#     415                 dbname,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210                 client._process_response(response_doc, session)
#     211             if check:
# --> 212                 helpers_shared._check_command_response(
#     213                     response_doc,
#     214                     conn.max_wire_version,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/helpers_shared.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     282         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     283
# --> 284     raise OperationFailure(errmsg, code, response, max_wire_version)
#     285
#     286
#
# OperationFailure: you are over your space quota, using 515 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 515 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}
